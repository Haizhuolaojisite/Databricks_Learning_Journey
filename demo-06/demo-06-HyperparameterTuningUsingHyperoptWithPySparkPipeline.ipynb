# %%
import mlflow
 
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.feature import StandardScaler, VectorAssembler, StringIndexer, OneHotEncoder

from hyperopt import fmin, tpe, hp, Trials, STATUS_OK

# %% [markdown]
# Loading the data
# link-
# https://www.kaggle.com/santoshd3/bank-customers?select=Churn+Modeling.csv

# %%
cust_attrition_data = spark.read.csv('/FileStore/datasets/Bank_customer.csv', header = 'true', inferSchema = 'true')

display(cust_attrition_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerId</th><th>Surname</th><th>CreditScore</th><th>Geography</th><th>Gender</th><th>Age</th><th>Tenure</th><th>Balance</th><th>NumOfProducts</th><th>HasCrCard</th><th>IsActiveMember</th><th>EstimatedSalary</th><th>Exited</th></tr></thead><tbody><tr><td>15634602</td><td>Hargrave</td><td>619</td><td>France</td><td>Female</td><td>42</td><td>2</td><td>0.0</td><td>1</td><td>Yes</td><td>Yes</td><td>101348.88</td><td>Yes</td></tr><tr><td>15647311</td><td>Hill</td><td>608</td><td>Spain</td><td>Female</td><td>41</td><td>1</td><td>83807.86</td><td>1</td><td>No</td><td>Yes</td><td>112542.58</td><td>No</td></tr><tr><td>15619304</td><td>Onio</td><td>502</td><td>France</td><td>Female</td><td>42</td><td>8</td><td>159660.8</td><td>3</td><td>Yes</td><td>No</td><td>113931.57</td><td>Yes</td></tr><tr><td>15701354</td><td>Boni</td><td>699</td><td>France</td><td>Female</td><td>39</td><td>1</td><td>0.0</td><td>2</td><td>No</td><td>No</td><td>93826.63</td><td>No</td></tr><tr><td>15737888</td><td>Mitchell</td><td>850</td><td>Spain</td><td>Female</td><td>43</td><td>2</td><td>125510.82</td><td>1</td><td>Yes</td><td>Yes</td><td>79084.1</td><td>No</td></tr><tr><td>15574012</td><td>Chu</td><td>645</td><td>Spain</td><td>Male</td><td>44</td><td>8</td><td>113755.78</td><td>2</td><td>Yes</td><td>No</td><td>149756.71</td><td>Yes</td></tr><tr><td>15592531</td><td>Bartlett</td><td>822</td><td>France</td><td>Others</td><td>50</td><td>7</td><td>0.0</td><td>2</td><td>Yes</td><td>Yes</td><td>10062.8</td><td>No</td></tr><tr><td>15656148</td><td>Obinna</td><td>376</td><td>Germany</td><td>Female</td><td>29</td><td>4</td><td>115046.74</td><td>4</td><td>Yes</td><td>No</td><td>119346.88</td><td>Yes</td></tr><tr><td>15792365</td><td>He</td><td>501</td><td>France</td><td>Male</td><td>44</td><td>4</td><td>142051.07</td><td>2</td><td>No</td><td>Yes</td><td>74940.5</td><td>No</td></tr><tr><td>15592389</td><td>H?</td><td>684</td><td>France</td><td>Male</td><td>27</td><td>2</td><td>134603.88</td><td>1</td><td>Yes</td><td>Yes</td><td>71725.73</td><td>No</td></tr><tr><td>15767821</td><td>Bearce</td><td>528</td><td>France</td><td>Male</td><td>31</td><td>6</td><td>102016.72</td><td>2</td><td>No</td><td>No</td><td>80181.12</td><td>No</td></tr><tr><td>15737173</td><td>Andrews</td><td>497</td><td>Spain</td><td>Male</td><td>24</td><td>3</td><td>0.0</td><td>2</td><td>Yes</td><td>No</td><td>76390.01</td><td>No</td></tr><tr><td>15632264</td><td>Kay</td><td>476</td><td>France</td><td>Female</td><td>34</td><td>10</td><td>0.0</td><td>2</td><td>Yes</td><td>No</td><td>26260.98</td><td>No</td></tr><tr><td>15691483</td><td>Chin</td><td>549</td><td>France</td><td>Female</td><td>25</td><td>5</td><td>0.0</td><td>2</td><td>No</td><td>No</td><td>190857.79</td><td>No</td></tr><tr><td>15600882</td><td>Scott</td><td>635</td><td>Spain</td><td>Female</td><td>35</td><td>7</td><td>0.0</td><td>2</td><td>Yes</td><td>Yes</td><td>65951.65</td><td>No</td></tr><tr><td>15643966</td><td>Goforth</td><td>616</td><td>Germany</td><td>Male</td><td>45</td><td>3</td><td>143129.41</td><td>2</td><td>No</td><td>Yes</td><td>64327.26</td><td>No</td></tr><tr><td>15737452</td><td>Romeo</td><td>653</td><td>Germany</td><td>Male</td><td>58</td><td>1</td><td>132602.88</td><td>1</td><td>Yes</td><td>No</td><td>5097.67</td><td>Yes</td></tr><tr><td>15788218</td><td>Henderson</td><td>549</td><td>Spain</td><td>Others</td><td>24</td><td>9</td><td>0.0</td><td>2</td><td>Yes</td><td>Yes</td><td>14406.41</td><td>No</td></tr><tr><td>15661507</td><td>Muldrow</td><td>587</td><td>Spain</td><td>Male</td><td>45</td><td>6</td><td>0.0</td><td>1</td><td>No</td><td>No</td><td>158684.81</td><td>No</td></tr><tr><td>15568982</td><td>Hao</td><td>726</td><td>France</td><td>Female</td><td>24</td><td>6</td><td>0.0</td><td>2</td><td>Yes</td><td>Yes</td><td>54724.03</td><td>No</td></tr><tr><td>15577657</td><td>McDonald</td><td>732</td><td>Fra ...

# %% [markdown]
# Dropping irrelevant columns

# %%
cust_attrition_data = cust_attrition_data.drop(*['CustomerId', 'Surname'])

feature_cols = cust_attrition_data.drop('Exited').columns

# %% [markdown]
# Randomly splitting the whole data into training,validation,test sets

# %%
training_data, test_data = cust_attrition_data.randomSplit([0.7, 0.3], seed = 42)

# %% [markdown]
# We are using  MLflow to track training.
# Specifying  "nested=True" since this single model will be logged as a child run of Hyperopt's run.
#
# This train_tree() function:
#    - takes hyperparameters as inputs (for tuning later)
#    - returns the Area Under PR score on the test dataset.We are using Area under PR score instead of AUC-ROC as the dataset is imbalanced
#
#   Wrapping code as a function makes it easier to reuse the code later with Hyperopt.
#   Chaining  stringIndexer, encoder , va1 , standardcaler ,va2, labelindexer, rf indexertogether into a single ML Pipeline.
#   Also Defining an evaluation metric(F1) and evaluate the model on the validation dataset.

# %%
def train_tree(maxDepth, numTrees , impurity):
    
    with mlflow.start_run(nested = True):

        categoricalCols = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
        numericCols = ['Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
 
        stringIndexer = StringIndexer(inputCols = categoricalCols, 
                                      outputCols = [x + 'Index' for x in categoricalCols]) 
        encoder = OneHotEncoder(inputCols = stringIndexer.getOutputCols(), 
                                outputCols = [x + 'OHE' for x in categoricalCols])
        
        featureArr = [x + 'OHE' for x in categoricalCols] + [('scaled_' + f) for f in numericCols]

        va1 = [VectorAssembler(inputCols = [f], 
                               outputCol = ('vec_' + f)) for f in numericCols]
        ss = [StandardScaler(inputCol = 'vec_' + f, outputCol = 'scaled_' + f, 
                             withMean = True, withStd = True) for f in numericCols]

        va2 = VectorAssembler(inputCols = featureArr, outputCol = 'features')
        
        indexer = StringIndexer(inputCol = 'Exited', outputCol = 'indexedLabel')

        rf = RandomForestClassifier(labelCol = 'indexedLabel', maxDepth = maxDepth,
                                    numTrees = numTrees, impurity = impurity)
    
   
        pipeline = Pipeline(stages = [stringIndexer, encoder] + va1 + ss + [va2, indexer, rf] )
        model = pipeline.fit(training_data)
 
        evaluator = BinaryClassificationEvaluator(labelCol = 'indexedLabel',
                                                  metricName = 'areaUnderPR')
 
        predictions = model.transform(test_data)
        test_metric = evaluator.evaluate(predictions)
        
        mlflow.log_param('Max_depth', maxDepth)
        mlflow.log_param('Num_trees', numTrees)
        mlflow.log_param('Impurity', impurity)
        mlflow.log_metric('areaUnderPR', test_metric)
        
        mlflow.spark.log_model(spark_model = model, artifact_path = 'sklearn-model')
 
        return model, test_metric

# %%
initial_model, test_metric = train_tree(maxDepth = 2, numTrees = 10 , impurity = 'gini')

print(f'The trained RandomForestClassifier achieved an AreaUnderPR score of {test_metric} on the test data')
# Out:
# 2022/11/08 13:58:36 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpxcohg3kl, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
# The trained RandomForestClassifier achieved an AreaUnderPR score of 0.5994082364955033 on the test data

# %% [markdown]
# Hyperopt expects you to return a loss (for which lower is better), so take the negative of the AreaUnderPR (for which higher is better).

# %%
def train_with_hyperopt(params):
    
    numTrees = params['numTrees']
    maxDepth = params['maxDepth']
    impurity = params['impurity']
 
    model, areaunderpr = train_tree(maxDepth, numTrees ,impurity)

    loss = - areaunderpr
    
    return {'loss': loss, 'status': STATUS_OK}

# %% [markdown]
# Search space is defined.Note that here we are using hp.quniform which results in continuous values.As we are casting both numtrees and maxdepth to integer above,it won't throw errors.Note that the search space is reduced in comparison to demo-05's search space as it was taking too long with demo-05's search space

# %%
from hyperopt.pyll import scope

search_space = {'numTrees':scope.int(hp.quniform('n_trees', 100, 200, 10)),
                'maxDepth':scope.int(hp.quniform('maxDepth', 2, 8, 1 )),
                'impurity':hp.choice('impurity', ['gini', 'entropy'])}

# %%
algo = tpe.suggest
 
with mlflow.start_run():
    best_params = fmin(
        fn = train_with_hyperopt,
        space = search_space,
        algo = algo,
        max_evals = 16)
# Out:
#   0%|          | 0/16 [00:00<?, ?trial/s, best loss=?]2022/11/08 13:59:53 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpc3n93asu, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#   6%|▋         | 1/16 [00:57<14:15, 57.04s/trial, best loss: -0.6893063407551343]2022/11/08 14:00:50 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmplipw76ry, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  12%|█▎        | 2/16 [01:54<13:20, 57.17s/trial, best loss: -0.6893063407551343]2022/11/08 14:01:45 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpwtpcl17u, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  19%|█▉        | 3/16 [02:48<12:08, 56.04s/trial, best loss: -0.6893063407551343]2022/11/08 14:02:34 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpqwue3wqu, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  25%|██▌       | 4/16 [03:38<10:41, 53.42s/trial, best loss: -0.6893063407551343]2022/11/08 14:03:31 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpw444iw5w, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  31%|███▏      | 5/16 [04:35<10:00, 54.61s/trial, best loss: -0.6893063407551343]2022/11/08 14:04:26 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpjsh3crr6, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  38%|███▊      | 6/16 [05:29<09:06, 54.64s/trial, best loss: -0.6893063407551343]2022/11/08 14:05:22 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpfwx7skmy, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  44%|████▍     | 7/16 [06:26<08:16, 55.19s/trial, best loss: -0.693725982701601] 2022/11/08 14:06:16 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpu9msx1ap, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  50%|█████     | 8/16 [07:19<07:16, 54.61s/trial, best loss: -0.693725982701601]2022/11/08 14:07:13 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmp0biom072, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  56%|█████▋    | 9/16 [08:16<06:27, 55.41s/trial, best loss: -0.693725982701601]2022/11/08 14:08:05 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpdetobqr9, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  62%|██████▎   | 10/16 [09:09<05:27, 54.55s/trial, best loss: -0.693725982701601]2022/11/08 14:09:05 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmp849wm5s6, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  69%|██████▉   | 11/16 [10:09<04:40, 56.19s/trial, best loss: -0.693725982701601]2022/11/08 14:09:58 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpz8et5vf1, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  75%|███████▌  | 12/16 [11:01<03:39, 54.99s/trial, best loss: -0.693725982701601]2022/11/08 14:10:50 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpz_vq93tj, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  81%|████████▏ | 13/16 [11:53<02:42, 54.19s/trial, best loss: -0.693725982701601]2022/11/08 14:11:42 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpujmj_0cg, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  88%|████████▊ | 14/16 [12:45<01:47, 53.54s/trial, best loss: -0.693725982701601]2022/11/08 14:12:43 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmppi4bda6_, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
#  94%|█████████▍| 15/16 [13:47<00:55, 55.89s/trial, best loss: -0.6983013285434326]2022/11/08 14:13:37 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpfa8u23y9, flavor: spark), fall back to return ['pyspark==3.3.0']. Set logging level to DEBUG to see the full traceback.
#
# 100%|██████████| 16/16 [14:41<00:00, 55.06s/trial, best loss: -0.6983013285434326]

# %% [markdown]
# #### TODO Recording:
# - Once training is complete, click on "experiment"
# - Expand and show all the run under the top-level experiment
# - Sort by AreaUnderPR in descending order
# - Click on the best run
# - Show "Parameters" and "Metrics"

# %% [markdown]
# Best parameters are obtained

# %%
best_params
# Out:
# Out[25]: {'impurity': 1, 'maxDepth': 8.0, 'n_trees': 150.0}
